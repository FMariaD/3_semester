# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as so
import csv


x_data, y_data = [], []
with open("Segment(max).txt", encoding='utf-8') as r_file:
    
    file = csv.reader(r_file, delimiter = ";")
    for row in file:
            x_data.append(row[1])
            y_data.append(row[0])

                      
for i in range(0, len(x_data)):
    x_data[i] = float(x_data[i])
for i in range(0, len(y_data)):
    y_data[i] = float(y_data[i])
    
def f(x, a):
    y = a/x
    return y

G = so.curve_fit(f, x_data, y_data)
a1 = G[0][0]

new_y = []
for i in range(0, len(x_data)):
    new_y.append(f(x_data[i], a1))

plt.figure(figsize=(18, 10))
plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')
plt.plot(x_data, new_y, label=r'theoretical', color='blue')
plt.xlabel(r'$Max\ Number$', fontsize=14)
plt.ylabel(r'$Probability$', fontsize=14)
plt.title(r'$SegmentState$', fontsize=16)
plt.legend(loc='best', fontsize=12)
plt.grid(True)

a1_string = str(round(a1, 1))
plt.text(600, 0.10, 'теоретическая зависимость: y = ' + a1_string + ' / x', fontsize = 14)
                      
plt.show()
# Out:
# <ipython-input-9-5f5a6bccfe47>:33: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as so
import csv


x_data, y_data = [], []
with open("Segment(count).txt", encoding='utf-8') as r_file:
    
    file = csv.reader(r_file, delimiter = ";")
    for row in file:
            x_data.append(row[1])
            y_data.append(row[0])

                      
for i in range(0, len(x_data)):
    x_data[i] = float(x_data[i])
for i in range(0, len(y_data)):
    y_data[i] = float(y_data[i])

plt.figure(figsize=(18, 10))
plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')
plt.xlabel(r'$Quantity\ of\ Tests$', fontsize=14)
plt.ylabel(r'$Probability$', fontsize=14)
plt.title(r'$SegmentState$', fontsize=16)
plt.legend(loc='best', fontsize=12)
plt.grid(True)
                      
plt.show()
# Out:
# <ipython-input-1-df7541cfa2ac>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as so
import csv


x_data, y_data = [], []
with open("Discrete(count).txt", encoding='utf-8') as r_file:
    
    file = csv.reader(r_file, delimiter = ";")
    for row in file:
            x_data.append(row[1])
            y_data.append(row[0])

                      
for i in range(0, len(x_data)):
    x_data[i] = float(x_data[i])
for i in range(0, len(y_data)):
    y_data[i] = float(y_data[i])

plt.figure(figsize=(18, 10))
plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')
plt.xlabel(r'$Quantity\ of\ Tests$', fontsize=14)
plt.ylabel(r'$Probability$', fontsize=14)
plt.title(r'$DiscreteState$', fontsize=16)
plt.legend(loc='best', fontsize=12)
plt.grid(True)
                      
plt.show()
# Out:
# <ipython-input-2-2405aaca4755>:22: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.optimize as so
import csv


x_data, y_data = [], []
with open("Discrete(max).txt", encoding='utf-8') as r_file:
    
    file = csv.reader(r_file, delimiter = ";")
    for row in file:
            x_data.append(row[1])
            y_data.append(row[0])

                      
for i in range(0, len(x_data)):
    x_data[i] = float(x_data[i])
for i in range(0, len(y_data)):
    y_data[i] = float(y_data[i])
    
def f(x, a):
    y = a/x
    return y

G = so.curve_fit(f, x_data, y_data)
a1 = G[0][0]

new_y = []
for i in range(0, len(x_data)):
    new_y.append(f(x_data[i], a1))

plt.figure(figsize=(18, 10))
plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')
plt.plot(x_data, new_y, label=r'theoretical', color='blue')
plt.xlabel(r'$Max\ Number$', fontsize=14)
plt.ylabel(r'$Probability$', fontsize=14)
plt.title(r'$DiscreteState$', fontsize=16)
plt.legend(loc='best', fontsize=12)
plt.grid(True)

a1_string = str(round(a1, 1))
plt.text(600, 0.009, 'теоретическая зависимость: y = ' + a1_string + ' / x', fontsize = 14)
                      
plt.show()
# Out:
# <ipython-input-11-ad84e879dd83>:33: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x_data, y_data, 'ro', label=r'experimental', color='orange')
